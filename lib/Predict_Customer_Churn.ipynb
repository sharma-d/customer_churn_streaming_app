# %% [markdown]
# ### Import Libraries

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score,classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from matplotlib import pyplot as plt
from sklearn.preprocessing import OrdinalEncoder
import numpy as np
from sklearn.feature_selection import RFE
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
# drive.mount('/content/drive')
df = pd.read_csv('/Users/deepshikasharma/Desktop/Data Science Projects/customer_churn/data_regression.csv')

# %% [markdown]
# ### Logistic Regression Model

# %%
def prepare_model_smote(df,class_col,cols_to_exclude):
# Synthetic Minority Oversampling Technique. Generates new instances from existing minority cases that you supply as input. 
    from sklearn.model_selection import train_test_split
    import numpy as np
    from imblearn.over_sampling import SMOTE
    cols=df.select_dtypes(include=np.number).columns.tolist() 
    X=df[cols]
    X = X[X.columns.difference([class_col])]
    X = X[X.columns.difference(cols_to_exclude)]
    y=df[class_col]
    global X_train, X_test, y_train, y_test
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
    sm = SMOTE(random_state=0, sampling_strategy=1.0)
    X_train, y_train = sm.fit_resample(X_train, y_train) 

def run_model(X_train,X_test,y_train,y_test):
    from sklearn.linear_model import LogisticRegression
    from sklearn.metrics import roc_auc_score,classification_report
    global logreg #Defines the logistic model as a global model that can be used outside of this function
  # Fitting the logistic regression
    logreg = LogisticRegression(random_state = 13)
    logreg.fit(X_train, y_train)
  # Predicting y values
    global y_pred # Defines the Y_Pred as a global variable that can be used outside of this function
    y_pred = logreg.predict(X_test)
    logit_roc_auc = roc_auc_score(y_test, logreg.predict(X_test))
    print(classification_report(y_test, y_pred))
    print("The area under the curve is: %0.2f"%logit_roc_auc)

# %%
df = df.dropna() # cleaning up null values

# %%
prepare_model_smote(df,class_col = 'churn',cols_to_exclude=['customer_id','phone_no', 'year'])

# %%
run_model(X_train,X_test,y_train,y_test)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.65      0.77       513
#          1.0       0.19      0.67      0.29        63
#
#     accuracy                           0.65       576
#    macro avg       0.56      0.66      0.53       576
# weighted avg       0.86      0.65      0.72       576
#
# The area under the curve is: 0.66

# %% [markdown]
# ### Decision Tree Model

# %%
def prepare_model_smote(df,class_col,cols_to_exclude):
# Synthetic Minority Oversampling Technique. Generates new instances from existing minority cases that you supply as input. 
    from sklearn.model_selection import train_test_split
    import numpy as np
    from imblearn.over_sampling import SMOTE
    cols=df.select_dtypes(include=np.number).columns.tolist() 
    X=df[cols]
    X = X[X.columns.difference([class_col])]
    X = X[X.columns.difference(cols_to_exclude)]
    y=df[class_col]
    global X_train, X_test, y_train, y_test
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
    sm = SMOTE(random_state=0, sampling_strategy=1.0)
    X_train, y_train = sm.fit_resample(X_train, y_train)

# %%
def run_model(X_train,X_test,y_train,y_test):
    from sklearn.tree import DecisionTreeClassifier
    from sklearn.metrics import roc_auc_score,classification_report
    global dectree #Defines the logistic model as a global model that can be used outside of this function
  # Fitting the logistic regression
    dectree = DecisionTreeClassifier(random_state = 13,criterion = 'entropy')
    dectree.fit(X_train, y_train)
  # Predicting y values
    global y_pred #Defines the Y_Pred as a global variable that can be used outside of this function
    y_pred = dectree.predict(X_test)
    dectree_roc_auc = roc_auc_score(y_test, dectree.predict(X_test))
    print(classification_report(y_test, y_pred))
    print("The area under the curve is: %0.2f"%dectree_roc_auc)
  # All parameters of the decision tree classifier in scikit-learn can be found here: https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html#sklearn.tree.DecisionTreeClassifier

# %%
prepare_model_smote(df,class_col = 'churn',cols_to_exclude=['customer_id','phone_no', 'year'])

# %%
run_model(X_train,X_test,y_train,y_test)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.84      0.89       513
#          1.0       0.31      0.57      0.40        63
#
#     accuracy                           0.81       576
#    macro avg       0.62      0.71      0.64       576
# weighted avg       0.87      0.81      0.84       576
#
# The area under the curve is: 0.71

# %%
def roc_curve (model,X_test,y_test):
    import matplotlib.pyplot as plt 
    from sklearn.metrics import roc_auc_score
    from sklearn.metrics import roc_curve
    logit_roc_auc = roc_auc_score(y_test, model.predict(X_test))
    fpr, tpr, thresholds = roc_curve(y_test, model.predict(X_test))
  # Setting the graph area
    plt.figure()
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])

  # Plotting the worst line possiple
    plt.plot([0, 1], [0, 1],'b--')

  # Plotting the logistic regression we have built
    plt.plot(fpr, tpr, color='darkorange', label='Model (area = %0.2f)' % logit_roc_auc)

  # Adding labels and etc
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve')
    plt.legend(loc="lower right")
    plt.savefig('Log_ROC')
    plt.show()

# %%
def confusion_matrix(y_test,y_pred):
    from sklearn.metrics import confusion_matrix
    confusion_matrix = confusion_matrix(y_test, y_pred)
    print(confusion_matrix)
    tn, fp, fn, tp = confusion_matrix.ravel()
    print('TN: %0.2f'% tn)
    print('TP: %0.2f'% tp)
    print('FP: %0.2f'%fp)
    print('FN: %0.2f'%fn)

# %%
roc_curve (dectree,X_test,y_test)

# %%
confusion_matrix(y_test,y_pred)
# Out:
# [[432  81]
#  [ 27  36]]
# TN: 432.00
# TP: 36.00
# FP: 81.00
# FN: 27.00

# %%
def plot_model(model,class_names,max_depth=None,figsize=(20,20),fontsize=1):
    plt.figure(figsize=figsize)
    tree.plot_tree(dectree
                   ,feature_names = dectree.feature_names_in_
                   ,fontsize=fontsize
                   ,max_depth = max_depth
                   ,class_names=class_names
                   ,filled = True);

# %%
plot_model(dectree,['not churn','churn'])

# %%
plot_model(dectree,['not churn','churn'],max_depth = 2,figsize=(20,20),fontsize=10)

# %%
def read_tree (model):
  # From - > https://scikit-learn.org/stable/auto_examples/tree/plot_unveil_tree_structure.html, with few adaptations
    n_nodes = model.tree_.node_count
    children_left = model.tree_.children_left
    children_right = model.tree_.children_right
    feature = model.tree_.feature
    feature_names = model.feature_names_in_
    threshold = model.tree_.threshold
    node_depth = np.zeros(shape=n_nodes, dtype=np.int64)
    is_leaves = np.zeros(shape=n_nodes, dtype=bool)
    stack = [(0, 0)]  # start with the root node id (0) and its depth (0)
    while len(stack) > 0:
        # `pop` ensures each node is only visited once
        node_id, depth = stack.pop()
        node_depth[node_id] = depth
        # If the left and right child of a node is not the same we have a split node
        is_split_node = children_left[node_id] != children_right[node_id]
      # If a split node, append left and right children and depth to `stack`
      # so we can loop through them
    if is_split_node:
        stack.append((children_left[node_id], depth + 1))
        stack.append((children_right[node_id], depth + 1))
    else:
        is_leaves[node_id] = True

    print(
      "The binary tree structure has {n} nodes and has "
      "the following tree structure:\n".format(n=n_nodes))
    for i in range(n_nodes):
        if is_leaves[i]:
            print(
              "{space}node={node} is a leaf node.".format(
                  space=node_depth[i] * "\t", node=i))
        else:
            print(
              "{space}node={node} is a split node: "
              "go to node {left} if {feature} <= {threshold} "
              "else to node {right}.".format(
                  space=node_depth[i] * "\t",
                  node=i,
                  left=children_left[i],
                  feature=feature_names[feature[i]],
                  threshold=round(threshold[i],0),
                  right=children_right[i],))

# %%
read_tree(dectree)
# Out:
# The binary tree structure has 493 nodes and has the following tree structure:
#
# node=0 is a split node: go to node 1 if maximum_daily_mins <= 40.0 else to node 352.
# node=1 is a split node: go to node 2 if customer_support_calls <= 4.0 else to node 313.
# node=2 is a split node: go to node 3 if maximum_days_inactive <= 3.0 else to node 190.
# node=3 is a split node: go to node 4 if videos_watched <= 2.0 else to node 73.
# node=4 is a split node: go to node 5 if no_of_days_subscribed <= 88.0 else to node 20.
# node=5 is a split node: go to node 6 if minimum_daily_mins <= 8.0 else to node 7.
# node=6 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=7 is a split node: go to node 8 if minimum_daily_mins <= 10.0 else to node 19.
# node=8 is a split node: go to node 9 if age <= 36.0 else to node 12.
# node=9 is a split node: go to node 10 if maximum_daily_mins <= 19.0 else to node 11.
# node=10 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=11 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=12 is a split node: go to node 13 if no_of_days_subscribed <= 58.0 else to node 14.
# node=13 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=14 is a split node: go to node 15 if minimum_daily_mins <= 9.0 else to node 16.
# node=15 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=16 is a split node: go to node 17 if age <= 50.0 else to node 18.
# node=17 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=18 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=19 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=20 is a split node: go to node 21 if weekly_max_night_mins <= 96.0 else to node 34.
# node=21 is a split node: go to node 22 if no_of_days_subscribed <= 124.0 else to node 31.
# node=22 is a split node: go to node 23 if maximum_daily_mins <= 37.0 else to node 30.
# node=23 is a split node: go to node 24 if weekly_max_night_mins <= 79.0 else to node 25.
# node=24 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=25 is a split node: go to node 26 if weekly_max_night_mins <= 90.0 else to node 29.
# node=26 is a split node: go to node 27 if maximum_days_inactive <= 2.0 else to node 28.
# node=27 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=28 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=29 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=30 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=31 is a split node: go to node 32 if no_of_days_subscribed <= 212.0 else to node 33.
# node=32 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=33 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=34 is a split node: go to node 35 if age <= 57.0 else to node 72.
# node=35 is a split node: go to node 36 if no_of_days_subscribed <= 95.0 else to node 39.
# node=36 is a split node: go to node 37 if maximum_daily_mins <= 31.0 else to node 38.
# node=37 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=38 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=39 is a split node: go to node 40 if no_of_days_subscribed <= 108.0 else to node 45.
# node=40 is a split node: go to node 41 if weekly_mins_watched <= 186.0 else to node 44.
# node=41 is a split node: go to node 42 if customer_support_calls <= 2.0 else to node 43.
# node=42 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=43 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=44 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=45 is a split node: go to node 46 if no_of_days_subscribed <= 152.0 else to node 69.
# node=46 is a split node: go to node 47 if maximum_daily_mins <= 17.0 else to node 48.
# node=47 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=48 is a split node: go to node 49 if minimum_daily_mins <= 7.0 else to node 52.
# node=49 is a split node: go to node 50 if no_of_days_subscribed <= 142.0 else to node 51.
# node=50 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=51 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=52 is a split node: go to node 53 if maximum_days_inactive <= 3.0 else to node 54.
# node=53 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=54 is a split node: go to node 55 if age <= 42.0 else to node 68.
# node=55 is a split node: go to node 56 if weekly_max_night_mins <= 98.0 else to node 57.
# node=56 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=57 is a split node: go to node 58 if minimum_daily_mins <= 8.0 else to node 63.
# node=58 is a split node: go to node 59 if customer_support_calls <= 0.0 else to node 62.
# node=59 is a split node: go to node 60 if no_of_days_subscribed <= 118.0 else to node 61.
# node=60 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=61 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=62 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=63 is a split node: go to node 64 if videos_watched <= 2.0 else to node 67.
# node=64 is a split node: go to node 65 if no_of_days_subscribed <= 126.0 else to node 66.
# node=65 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=66 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=67 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=68 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=69 is a split node: go to node 70 if weekly_mins_watched <= 257.0 else to node 71.
# node=70 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=71 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=72 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=73 is a split node: go to node 74 if weekly_mins_watched <= 264.0 else to node 121.
# node=74 is a split node: go to node 75 if age <= 28.0 else to node 86.
# node=75 is a split node: go to node 76 if maximum_daily_mins <= 17.0 else to node 81.
# node=76 is a split node: go to node 77 if weekly_max_night_mins <= 106.0 else to node 80.
# node=77 is a split node: go to node 78 if no_of_days_subscribed <= 154.0 else to node 79.
# node=78 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=79 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=80 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=81 is a split node: go to node 82 if videos_watched <= 10.0 else to node 83.
# node=82 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=83 is a split node: go to node 84 if weekly_max_night_mins <= 68.0 else to node 85.
# node=84 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=85 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=86 is a split node: go to node 87 if age <= 52.0 else to node 114.
# node=87 is a split node: go to node 88 if customer_support_calls <= 2.0 else to node 93.
# node=88 is a split node: go to node 89 if maximum_days_inactive <= 3.0 else to node 92.
# node=89 is a split node: go to node 90 if minimum_daily_mins <= 8.0 else to node 91.
# node=90 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=91 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=92 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=93 is a split node: go to node 94 if maximum_daily_mins <= 23.0 else to node 109.
# node=94 is a split node: go to node 95 if videos_watched <= 4.0 else to node 104.
# node=95 is a split node: go to node 96 if weekly_max_night_mins <= 90.0 else to node 97.
# node=96 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=97 is a split node: go to node 98 if maximum_daily_mins <= 19.0 else to node 103.
# node=98 is a split node: go to node 99 if weekly_mins_watched <= 124.0 else to node 102.
# node=99 is a split node: go to node 100 if maximum_days_inactive <= 3.0 else to node 101.
# node=100 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=101 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=102 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=103 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=104 is a split node: go to node 105 if age <= 30.0 else to node 108.
# node=105 is a split node: go to node 106 if minimum_daily_mins <= 8.0 else to node 107.
# node=106 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=107 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=108 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=109 is a split node: go to node 110 if weekly_max_night_mins <= 78.0 else to node 113.
# node=110 is a split node: go to node 111 if age <= 34.0 else to node 112.
# node=111 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=112 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=113 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=114 is a split node: go to node 115 if maximum_daily_mins <= 28.0 else to node 116.
# node=115 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=116 is a split node: go to node 117 if no_of_days_subscribed <= 80.0 else to node 118.
# node=117 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=118 is a split node: go to node 119 if no_of_days_subscribed <= 174.0 else to node 120.
# node=119 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=120 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=121 is a split node: go to node 122 if weekly_max_night_mins <= 104.0 else to node 173.
# node=122 is a split node: go to node 123 if age <= 48.0 else to node 172.
# node=123 is a split node: go to node 124 if videos_watched <= 6.0 else to node 169.
# node=124 is a split node: go to node 125 if no_of_days_subscribed <= 136.0 else to node 166.
# node=125 is a split node: go to node 126 if no_of_days_subscribed <= 39.0 else to node 127.
# node=126 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=127 is a split node: go to node 128 if customer_support_calls <= 0.0 else to node 137.
# node=128 is a split node: go to node 129 if weekly_max_night_mins <= 76.0 else to node 132.
# node=129 is a split node: go to node 130 if no_of_days_subscribed <= 76.0 else to node 131.
# node=130 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=131 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=132 is a split node: go to node 133 if maximum_days_inactive <= 3.0 else to node 136.
# node=133 is a split node: go to node 134 if minimum_daily_mins <= 7.0 else to node 135.
# node=134 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=135 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=136 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=137 is a split node: go to node 138 if age <= 40.0 else to node 157.
# node=138 is a split node: go to node 139 if maximum_daily_mins <= 35.0 else to node 148.
# node=139 is a split node: go to node 140 if videos_watched <= 4.0 else to node 147.
# node=140 is a split node: go to node 141 if no_of_days_subscribed <= 82.0 else to node 142.
# node=141 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=142 is a split node: go to node 143 if customer_support_calls <= 2.0 else to node 144.
# node=143 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=144 is a split node: go to node 145 if minimum_daily_mins <= 10.0 else to node 146.
# node=145 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=146 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=147 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=148 is a split node: go to node 149 if minimum_daily_mins <= 9.0 else to node 154.
# node=149 is a split node: go to node 150 if weekly_mins_watched <= 333.0 else to node 153.
# node=150 is a split node: go to node 151 if minimum_daily_mins <= 5.0 else to node 152.
# node=151 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=152 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=153 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=154 is a split node: go to node 155 if weekly_max_night_mins <= 68.0 else to node 156.
# node=155 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=156 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=157 is a split node: go to node 158 if weekly_max_night_mins <= 89.0 else to node 161.
# node=158 is a split node: go to node 159 if weekly_max_night_mins <= 70.0 else to node 160.
# node=159 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=160 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=161 is a split node: go to node 162 if no_of_days_subscribed <= 94.0 else to node 165.
# node=162 is a split node: go to node 163 if weekly_mins_watched <= 278.0 else to node 164.
# node=163 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=164 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=165 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=166 is a split node: go to node 167 if weekly_max_night_mins <= 102.0 else to node 168.
# node=167 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=168 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=169 is a split node: go to node 170 if weekly_max_night_mins <= 102.0 else to node 171.
# node=170 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=171 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=172 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=173 is a split node: go to node 174 if weekly_mins_watched <= 311.0 else to node 189.
# node=174 is a split node: go to node 175 if no_of_days_subscribed <= 152.0 else to node 184.
# node=175 is a split node: go to node 176 if no_of_days_subscribed <= 64.0 else to node 179.
# node=176 is a split node: go to node 177 if age <= 46.0 else to node 178.
# node=177 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=178 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=179 is a split node: go to node 180 if age <= 23.0 else to node 183.
# node=180 is a split node: go to node 181 if minimum_daily_mins <= 10.0 else to node 182.
# node=181 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=182 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=183 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=184 is a split node: go to node 185 if customer_support_calls <= 0.0 else to node 186.
# node=185 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=186 is a split node: go to node 187 if weekly_mins_watched <= 277.0 else to node 188.
# node=187 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=188 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=189 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=190 is a split node: go to node 191 if maximum_days_inactive <= 4.0 else to node 192.
# node=191 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=192 is a split node: go to node 193 if minimum_daily_mins <= 13.0 else to node 234.
# node=193 is a split node: go to node 194 if no_of_days_subscribed <= 97.0 else to node 203.
# node=194 is a split node: go to node 195 if maximum_days_inactive <= 4.0 else to node 202.
# node=195 is a split node: go to node 196 if weekly_max_night_mins <= 74.0 else to node 201.
# node=196 is a split node: go to node 197 if weekly_max_night_mins <= 74.0 else to node 198.
# node=197 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=198 is a split node: go to node 199 if age <= 54.0 else to node 200.
# node=199 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=200 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=201 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=202 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=203 is a split node: go to node 204 if no_of_days_subscribed <= 116.0 else to node 225.
# node=204 is a split node: go to node 205 if minimum_daily_mins <= 11.0 else to node 206.
# node=205 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=206 is a split node: go to node 207 if weekly_max_night_mins <= 98.0 else to node 218.
# node=207 is a split node: go to node 208 if weekly_max_night_mins <= 86.0 else to node 213.
# node=208 is a split node: go to node 209 if weekly_mins_watched <= 196.0 else to node 212.
# node=209 is a split node: go to node 210 if maximum_daily_mins <= 19.0 else to node 211.
# node=210 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=211 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=212 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=213 is a split node: go to node 214 if age <= 40.0 else to node 217.
# node=214 is a split node: go to node 215 if videos_watched <= 2.0 else to node 216.
# node=215 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=216 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=217 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=218 is a split node: go to node 219 if age <= 35.0 else to node 224.
# node=219 is a split node: go to node 220 if no_of_days_subscribed <= 102.0 else to node 221.
# node=220 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=221 is a split node: go to node 222 if no_of_days_subscribed <= 108.0 else to node 223.
# node=222 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=223 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=224 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=225 is a split node: go to node 226 if weekly_max_night_mins <= 90.0 else to node 233.
# node=226 is a split node: go to node 227 if weekly_max_night_mins <= 80.0 else to node 228.
# node=227 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=228 is a split node: go to node 229 if weekly_mins_watched <= 261.0 else to node 232.
# node=229 is a split node: go to node 230 if videos_watched <= 6.0 else to node 231.
# node=230 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=231 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=232 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=233 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=234 is a split node: go to node 235 if weekly_mins_watched <= 189.0 else to node 240.
# node=235 is a split node: go to node 236 if no_of_days_subscribed <= 60.0 else to node 239.
# node=236 is a split node: go to node 237 if customer_support_calls <= 0.0 else to node 238.
# node=237 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=238 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=239 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=240 is a split node: go to node 241 if weekly_max_night_mins <= 74.0 else to node 242.
# node=241 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=242 is a split node: go to node 243 if maximum_daily_mins <= 37.0 else to node 300.
# node=243 is a split node: go to node 244 if maximum_daily_mins <= 32.0 else to node 281.
# node=244 is a split node: go to node 245 if no_of_days_subscribed <= 56.0 else to node 246.
# node=245 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=246 is a split node: go to node 247 if maximum_days_inactive <= 5.0 else to node 276.
# node=247 is a split node: go to node 248 if maximum_days_inactive <= 4.0 else to node 275.
# node=248 is a split node: go to node 249 if minimum_daily_mins <= 13.0 else to node 256.
# node=249 is a split node: go to node 250 if maximum_daily_mins <= 23.0 else to node 251.
# node=250 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=251 is a split node: go to node 252 if videos_watched <= 2.0 else to node 255.
# node=252 is a split node: go to node 253 if maximum_daily_mins <= 27.0 else to node 254.
# node=253 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=254 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=255 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=256 is a split node: go to node 257 if weekly_mins_watched <= 242.0 else to node 266.
# node=257 is a split node: go to node 258 if weekly_max_night_mins <= 88.0 else to node 259.
# node=258 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=259 is a split node: go to node 260 if weekly_max_night_mins <= 134.0 else to node 265.
# node=260 is a split node: go to node 261 if weekly_max_night_mins <= 98.0 else to node 264.
# node=261 is a split node: go to node 262 if maximum_daily_mins <= 26.0 else to node 263.
# node=262 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=263 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=264 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=265 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=266 is a split node: go to node 267 if customer_support_calls <= 0.0 else to node 270.
# node=267 is a split node: go to node 268 if weekly_max_night_mins <= 98.0 else to node 269.
# node=268 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=269 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=270 is a split node: go to node 271 if weekly_max_night_mins <= 96.0 else to node 274.
# node=271 is a split node: go to node 272 if weekly_mins_watched <= 259.0 else to node 273.
# node=272 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=273 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=274 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=275 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=276 is a split node: go to node 277 if no_of_days_subscribed <= 96.0 else to node 280.
# node=277 is a split node: go to node 278 if maximum_daily_mins <= 31.0 else to node 279.
# node=278 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=279 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=280 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=281 is a split node: go to node 282 if minimum_daily_mins <= 13.0 else to node 291.
# node=282 is a split node: go to node 283 if age <= 36.0 else to node 284.
# node=283 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=284 is a split node: go to node 285 if minimum_daily_mins <= 13.0 else to node 290.
# node=285 is a split node: go to node 286 if no_of_days_subscribed <= 76.0 else to node 287.
# node=286 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=287 is a split node: go to node 288 if customer_support_calls <= 0.0 else to node 289.
# node=288 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=289 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=290 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=291 is a split node: go to node 292 if no_of_days_subscribed <= 58.0 else to node 295.
# node=292 is a split node: go to node 293 if no_of_days_subscribed <= 22.0 else to node 294.
# node=293 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=294 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=295 is a split node: go to node 296 if minimum_daily_mins <= 13.0 else to node 299.
# node=296 is a split node: go to node 297 if videos_watched <= 4.0 else to node 298.
# node=297 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=298 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=299 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=300 is a split node: go to node 301 if maximum_days_inactive <= 4.0 else to node 308.
# node=301 is a split node: go to node 302 if videos_watched <= 4.0 else to node 303.
# node=302 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=303 is a split node: go to node 304 if maximum_daily_mins <= 39.0 else to node 305.
# node=304 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=305 is a split node: go to node 306 if videos_watched <= 7.0 else to node 307.
# node=306 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=307 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=308 is a split node: go to node 309 if age <= 40.0 else to node 310.
# node=309 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=310 is a split node: go to node 311 if maximum_days_inactive <= 5.0 else to node 312.
# node=311 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=312 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=313 is a split node: go to node 314 if maximum_daily_mins <= 28.0 else to node 333.
# node=314 is a split node: go to node 315 if maximum_daily_mins <= 23.0 else to node 316.
# node=315 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=316 is a split node: go to node 317 if no_of_days_subscribed <= 149.0 else to node 332.
# node=317 is a split node: go to node 318 if minimum_daily_mins <= 6.0 else to node 319.
# node=318 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=319 is a split node: go to node 320 if maximum_daily_mins <= 25.0 else to node 325.
# node=320 is a split node: go to node 321 if videos_watched <= 4.0 else to node 322.
# node=321 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=322 is a split node: go to node 323 if age <= 32.0 else to node 324.
# node=323 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=324 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=325 is a split node: go to node 326 if maximum_days_inactive <= 4.0 else to node 327.
# node=326 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=327 is a split node: go to node 328 if minimum_daily_mins <= 12.0 else to node 331.
# node=328 is a split node: go to node 329 if customer_support_calls <= 4.0 else to node 330.
# node=329 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=330 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=331 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=332 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=333 is a split node: go to node 334 if maximum_daily_mins <= 33.0 else to node 347.
# node=334 is a split node: go to node 335 if no_of_days_subscribed <= 112.0 else to node 342.
# node=335 is a split node: go to node 336 if videos_watched <= 4.0 else to node 337.
# node=336 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=337 is a split node: go to node 338 if videos_watched <= 7.0 else to node 341.
# node=338 is a split node: go to node 339 if no_of_days_subscribed <= 99.0 else to node 340.
# node=339 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=340 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=341 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=342 is a split node: go to node 343 if minimum_daily_mins <= 9.0 else to node 344.
# node=343 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=344 is a split node: go to node 345 if videos_watched <= 6.0 else to node 346.
# node=345 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=346 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=347 is a split node: go to node 348 if weekly_max_night_mins <= 73.0 else to node 351.
# node=348 is a split node: go to node 349 if no_of_days_subscribed <= 78.0 else to node 350.
# node=349 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=350 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=351 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=352 is a split node: go to node 353 if weekly_mins_watched <= 392.0 else to node 424.
# node=353 is a split node: go to node 354 if maximum_days_inactive <= 3.0 else to node 395.
# node=354 is a split node: go to node 355 if minimum_daily_mins <= 10.0 else to node 392.
# node=355 is a split node: go to node 356 if no_of_days_subscribed <= 57.0 else to node 357.
# node=356 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=357 is a split node: go to node 358 if weekly_max_night_mins <= 124.0 else to node 391.
# node=358 is a split node: go to node 359 if no_of_days_subscribed <= 78.0 else to node 370.
# node=359 is a split node: go to node 360 if weekly_mins_watched <= 362.0 else to node 361.
# node=360 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=361 is a split node: go to node 362 if weekly_max_night_mins <= 96.0 else to node 369.
# node=362 is a split node: go to node 363 if age <= 38.0 else to node 368.
# node=363 is a split node: go to node 364 if weekly_mins_watched <= 380.0 else to node 367.
# node=364 is a split node: go to node 365 if customer_support_calls <= 2.0 else to node 366.
# node=365 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=366 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=367 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=368 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=369 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=370 is a split node: go to node 371 if minimum_daily_mins <= 10.0 else to node 390.
# node=371 is a split node: go to node 372 if maximum_daily_mins <= 40.0 else to node 379.
# node=372 is a split node: go to node 373 if no_of_days_subscribed <= 133.0 else to node 378.
# node=373 is a split node: go to node 374 if maximum_days_inactive <= 3.0 else to node 375.
# node=374 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=375 is a split node: go to node 376 if weekly_max_night_mins <= 92.0 else to node 377.
# node=376 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=377 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=378 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=379 is a split node: go to node 380 if weekly_max_night_mins <= 98.0 else to node 389.
# node=380 is a split node: go to node 381 if no_of_days_subscribed <= 150.0 else to node 386.
# node=381 is a split node: go to node 382 if age <= 28.0 else to node 385.
# node=382 is a split node: go to node 383 if minimum_daily_mins <= 8.0 else to node 384.
# node=383 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=384 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=385 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=386 is a split node: go to node 387 if customer_support_calls <= 2.0 else to node 388.
# node=387 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=388 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=389 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=390 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=391 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=392 is a split node: go to node 393 if weekly_mins_watched <= 355.0 else to node 394.
# node=393 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=394 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=395 is a split node: go to node 396 if maximum_days_inactive <= 4.0 else to node 397.
# node=396 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=397 is a split node: go to node 398 if minimum_daily_mins <= 13.0 else to node 411.
# node=398 is a split node: go to node 399 if maximum_daily_mins <= 41.0 else to node 410.
# node=399 is a split node: go to node 400 if maximum_daily_mins <= 40.0 else to node 405.
# node=400 is a split node: go to node 401 if minimum_daily_mins <= 13.0 else to node 402.
# node=401 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=402 is a split node: go to node 403 if minimum_daily_mins <= 13.0 else to node 404.
# node=403 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=404 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=405 is a split node: go to node 406 if weekly_mins_watched <= 360.0 else to node 407.
# node=406 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=407 is a split node: go to node 408 if customer_support_calls <= 0.0 else to node 409.
# node=408 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=409 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=410 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=411 is a split node: go to node 412 if no_of_days_subscribed <= 136.0 else to node 419.
# node=412 is a split node: go to node 413 if customer_support_calls <= 2.0 else to node 414.
# node=413 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=414 is a split node: go to node 415 if no_of_days_subscribed <= 69.0 else to node 416.
# node=415 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=416 is a split node: go to node 417 if weekly_mins_watched <= 364.0 else to node 418.
# node=417 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=418 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=419 is a split node: go to node 420 if age <= 55.0 else to node 421.
# node=420 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=421 is a split node: go to node 422 if customer_support_calls <= 2.0 else to node 423.
# node=422 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=423 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=424 is a split node: go to node 425 if maximum_daily_mins <= 54.0 else to node 492.
# node=425 is a split node: go to node 426 if no_of_days_subscribed <= 33.0 else to node 427.
# node=426 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=427 is a split node: go to node 428 if no_of_days_subscribed <= 151.0 else to node 485.
# node=428 is a split node: go to node 429 if age <= 26.0 else to node 430.
# node=429 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=430 is a split node: go to node 431 if minimum_daily_mins <= 14.0 else to node 484.
# node=431 is a split node: go to node 432 if weekly_max_night_mins <= 100.0 else to node 453.
# node=432 is a split node: go to node 433 if maximum_daily_mins <= 47.0 else to node 444.
# node=433 is a split node: go to node 434 if minimum_daily_mins <= 13.0 else to node 443.
# node=434 is a split node: go to node 435 if maximum_daily_mins <= 45.0 else to node 442.
# node=435 is a split node: go to node 436 if videos_watched <= 4.0 else to node 437.
# node=436 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=437 is a split node: go to node 438 if minimum_daily_mins <= 9.0 else to node 439.
# node=438 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=439 is a split node: go to node 440 if no_of_days_subscribed <= 102.0 else to node 441.
# node=440 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=441 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=442 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=443 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=444 is a split node: go to node 445 if maximum_daily_mins <= 51.0 else to node 452.
# node=445 is a split node: go to node 446 if minimum_daily_mins <= 10.0 else to node 447.
# node=446 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=447 is a split node: go to node 448 if no_of_days_subscribed <= 85.0 else to node 451.
# node=448 is a split node: go to node 449 if weekly_max_night_mins <= 86.0 else to node 450.
# node=449 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=450 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=451 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=452 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=453 is a split node: go to node 454 if weekly_mins_watched <= 399.0 else to node 455.
# node=454 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=455 is a split node: go to node 456 if customer_support_calls <= 0.0 else to node 459.
# node=456 is a split node: go to node 457 if age <= 44.0 else to node 458.
# node=457 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=458 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=459 is a split node: go to node 460 if maximum_daily_mins <= 48.0 else to node 479.
# node=460 is a split node: go to node 461 if videos_watched <= 10.0 else to node 478.
# node=461 is a split node: go to node 462 if no_of_days_subscribed <= 57.0 else to node 463.
# node=462 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=463 is a split node: go to node 464 if no_of_days_subscribed <= 70.0 else to node 465.
# node=464 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=465 is a split node: go to node 466 if customer_support_calls <= 3.0 else to node 477.
# node=466 is a split node: go to node 467 if weekly_max_night_mins <= 110.0 else to node 474.
# node=467 is a split node: go to node 468 if no_of_days_subscribed <= 92.0 else to node 471.
# node=468 is a split node: go to node 469 if age <= 38.0 else to node 470.
# node=469 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=470 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=471 is a split node: go to node 472 if age <= 30.0 else to node 473.
# node=472 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=473 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=474 is a split node: go to node 475 if videos_watched <= 7.0 else to node 476.
# node=475 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=476 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=477 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=478 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=479 is a split node: go to node 480 if maximum_days_inactive <= 2.0 else to node 481.
# node=480 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=481 is a split node: go to node 482 if videos_watched <= 11.0 else to node 483.
# node=482 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=483 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=484 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=485 is a split node: go to node 486 if weekly_mins_watched <= 427.0 else to node 491.
# node=486 is a split node: go to node 487 if maximum_days_inactive <= 3.0 else to node 490.
# node=487 is a split node: go to node 488 if maximum_daily_mins <= 47.0 else to node 489.
# node=488 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=489 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=490 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=491 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.
# node=492 is a split node: go to node -1 if weekly_max_night_mins <= -2.0 else to node -1.

# %%
def plot_feature_importances(model):
    feature_importances = pd.Series(model.feature_importances_, index=model.feature_names_in_)
    feature_importances = feature_importances.sort_values(axis=0, ascending=False)
    fig, ax = plt.subplots()
    feature_importances.plot.bar()
    ax.set_title("Feature importances")
    fig.tight_layout()

# %%
plot_feature_importances(dectree)
